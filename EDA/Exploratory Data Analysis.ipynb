# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
aqi = pd.read_csv("aqi3.csv")

# %%
aqi.describe()
# Out:
#              S.No  Index Value
# count  239.000000   239.000000
# mean   120.000000   119.112971
# std     69.137544    50.559888
# min      1.000000    28.000000
# 25%     60.500000    85.000000
# 50%    120.000000   109.000000
# 75%    179.500000   144.000000
# max    239.000000   335.000000

# %%
aqi
# Out:
#      S.No           City   Air Quality  Index Value Prominent Pollutant  \
# 0       1       Agartala  Satisfactory           67                  O3
# 1       2           Agra  Satisfactory           84                PM10
# 2       3      Ahmedabad      Moderate          166           O3, PM2.5
# 3       4     Ahmednagar      Moderate          169                  O3
# 4       5         Aizawl      Moderate          107                PM10
# ..    ...            ...           ...          ...                 ...
# 234   235          Virar      Moderate          106               PM2.5
# 235   236   Virudhunagar  Satisfactory           86                PM10
# 236   237  Visakhapatnam      Moderate          111                PM10
# 237   238      Vrindavan  Satisfactory           93                PM10
# 238   239         Yadgir  Satisfactory          100                PM10
#
#     No. of Stations Participated/ Total Stations
# 0                                            1/2
# ...

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
sns.countplot(data=aqi, x='Air Quality', order=aqi['Air Quality'].value_counts().index)
plt.title('Distribution of Air Quality Categories')
plt.show()

# %%
sns.histplot(aqi['Index Value'], kde=True)
plt.title('Distribution of Index Values')
plt.show()

# %%
plt.figure(figsize=(9, 6))
sns.countplot(data=aqi, x='Prominent Pollutant', order=aqi['Prominent Pollutant'].value_counts().index)
plt.title('Distribution of Prominent Pollutants')
plt.xticks(rotation=45)
plt.show()

# %%
sns.boxplot(data=aqi, x='Air Quality', y='Index Value')
plt.title('Air Quality vs. Index Value')
plt.show()

# %%
plt.figure(figsize=(9,6))
sns.boxplot(data=aqi, x='Prominent Pollutant', y='Index Value')
plt.title('Prominent Pollutant vs. Index Value')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(25, 200))
sns.countplot(data=aqi, y='City', hue='Air Quality', order=aqi['City'].value_counts().index)
plt.title('City-wise Air Quality Distribution')
plt.show()

# %%
sns.pairplot(aqi)
plt.show()
